# %%
#import needed libraries
from sqlalchemy import create_engine
import pandas as pd
import os
from dotenv import load_dotenv
import urllib
import pyodbc

# %%
#Connecting to MS SQL Server database
load_dotenv()

#get parameters from environmnet var
pwd = os.getenv('mssql_pwd')
uid = os.getenv('mssql_uid')
#sql db details
driver = os.getenv('mssql_driver')
server = os.getenv('mssql_server')
database = os.getenv("mssql_database")

params = urllib.parse.quote_plus(f"DRIVER={driver};"
                            f"SERVER={server};"
                            f"DATABASE={database};"
                            "Trusted_Connection=yes;"
                            "TrustServerCertificate=yes")

mssql_engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

# %%
#Extracting table names to be loaded into postgres database

table_names_df = pd.read_sql_query(""" SELECT  '[' + table_catalog + '].[' + TABLE_SCHEMA + '].[' + table_name + ']' as table_name FROM INFORMATION_SCHEMA.TABLES 
                                        WHERE TABLE_NAME LIKE '%%' """, mssql_engine)

list_of_tables = list(table_names_df['table_name'])
list_of_tables
# Out:
# ['[AdventureWorks2019].[HumanResources].[EmployeePayHistory]',
#  '[AdventureWorks2019].[Sales].[SalesOrderHeaderSalesReason]',
#  '[AdventureWorks2019].[Sales].[SalesPerson]',
#  '[AdventureWorks2019].[Production].[Illustration]',
#  '[AdventureWorks2019].[HumanResources].[JobCandidate]',
#  '[AdventureWorks2019].[Production].[Location]',
#  '[AdventureWorks2019].[Person].[Password]',
#  '[AdventureWorks2019].[Sales].[SalesPersonQuotaHistory]',
#  '[AdventureWorks2019].[Person].[Person]',
#  '[AdventureWorks2019].[Sales].[SalesReason]',
#  '[AdventureWorks2019].[Sales].[SalesTaxRate]',
#  '[AdventureWorks2019].[Sales].[PersonCreditCard]',
#  '[AdventureWorks2019].[Person].[vAdditionalContactInfo]',
#  '[AdventureWorks2019].[Person].[PersonPhone]',
#  '[AdventureWorks2019].[HumanResources].[vEmployee]',
#  '[AdventureWorks2019].[Sales].[SalesTerritory]',
#  '[AdventureWorks2019].[HumanResources].[vEmployeeDepartment]',
#  '[AdventureWorks2019].[Person].[PhoneNumberType]',
#  '[AdventureWorks2019].[HumanResources].[vEmployeeDepartmentHistory]',
#  '[AdventureWorks2019].[Sales].[vIndividualCustomer]',
#  '[AdventureWorks2019].[Production].[Product]',
#  '[AdventureWorks2019].[Sales].[vPersonDemographics]',
#  '[AdventureWorks2019].[HumanResources].[vJobCandidate]',
#  '[AdventureWorks2019].[HumanResources].[vJobCandidateEmployment]',
#  '[AdventureWorks2019].[HumanResources].[vJobCandidateEducation]',
#  '[AdventureWorks2019].[Production].[vProductAndDescription]',
#  '[AdventureWorks2019].[Production].[vProductModelCatalogDescription]',
#  '[AdventureWorks2019].[Production].[vProductModelInstructions]',
#  '[AdventureWorks2019].[Sales].[vSalesPerson]',
#  '[AdventureWorks2019].[Sales].[SalesTerritoryHistory]',
#  '[AdventureWorks2019].[Sales].[vSalesPersonSalesByFiscalYears]',
#  '[AdventureWorks2019].[Person].[vStateProvinceCountryRegion]',
#  '[AdventureWorks2019].[Sales].[vStoreWithDemographics]',
#  '[AdventureWorks2019].[Sales].[vStoreWithContacts]',
#  '[AdventureWorks2019].[Production].[ScrapReason]',
#  '[AdventureWorks2019].[Sales].[vStoreWithAddresses]',
#  '[AdventureWorks2019].[Purchasing].[vVendorWithContacts]',
#  '[AdventureWorks2019].[HumanResources].[Shift]',
#  '[AdventureWorks2019].[Purchasing].[vVendorWithAddresses]',
#  '[AdventureWorks2019].[Production].[ProductCategory]',
#  '[AdventureWorks2019].[Purchasing].[ShipMethod]',
#  '[AdventureWorks2019].[Production].[ProductCostHistory]',
#  '[AdventureWorks2019].[Production].[ProductDescription]',
#  '[AdventureWorks2019].[Sales].[ShoppingCartItem]',
#  '[AdventureWorks2019].[Production].[ProductDocument]',
#  '[AdventureWorks2019].[dbo].[DatabaseLog]',
#  '[AdventureWorks2019].[Production].[ProductInventory]',
#  '[AdventureWorks2019].[Sales].[SpecialOffer]',
#  '[AdventureWorks2019].[dbo].[ErrorLog]',
#  '[AdventureWorks2019].[Production].[ProductListPriceHistory]',
#  '[AdventureWorks2019].[Person].[Address]',
#  '[AdventureWorks2019].[Sales].[SpecialOfferProduct]',
#  '[AdventureWorks2019].[Production].[ProductModel]',
#  '[AdventureWorks2019].[Person].[AddressType]',
#  '[AdventureWorks2019].[Person].[StateProvince]',
#  '[AdventureWorks2019].[Production].[ProductModelIllustration]',
#  '[AdventureWorks2019].[dbo].[AWBuildVersion]',
#  '[AdventureWorks2019].[Production].[ProductModelProductDescriptionCulture]',
#  '[AdventureWorks2019].[Production].[BillOfMaterials]',
#  '[AdventureWorks2019].[Sales].[Store]',
#  '[AdventureWorks2019].[Production].[ProductPhoto]',
#  '[AdventureWorks2019].[Production].[ProductProductPhoto]',
#  '[AdventureWorks2019].[Production].[TransactionHistory]',
#  '[AdventureWorks2019].[Production].[ProductReview]',
#  '[AdventureWorks2019].[Person].[BusinessEntity]',
#  '[AdventureWorks2019].[Production].[TransactionHistoryArchive]',
#  '[AdventureWorks2019].[Production].[ProductSubcategory]',
#  '[AdventureWorks2019].[Person].[BusinessEntityAddress]',
#  '[AdventureWorks2019].[Purchasing].[ProductVendor]',
#  '[AdventureWorks2019].[Person].[BusinessEntityContact]',
#  '[AdventureWorks2019].[Production].[UnitMeasure]',
#  '[AdventureWorks2019].[Purchasing].[Vendor]',
#  '[AdventureWorks2019].[Person].[ContactType]',
#  '[AdventureWorks2019].[Sales].[CountryRegionCurrency]',
#  '[AdventureWorks2019].[Person].[CountryRegion]',
#  '[AdventureWorks2019].[Production].[WorkOrder]',
#  '[AdventureWorks2019].[Purchasing].[PurchaseOrderDetail]',
#  '[AdventureWorks2019].[Sales].[CreditCard]',
#  '[AdventureWorks2019].[Production].[Culture]',
#  '[AdventureWorks2019].[Production].[WorkOrderRouting]',
#  '[AdventureWorks2019].[Sales].[Currency]',
#  '[AdventureWorks2019].[Purchasing].[PurchaseOrderHeader]',
#  '[AdventureWorks2019].[Sales].[CurrencyRate]',
#  '[AdventureWorks2019].[Sales].[Customer]',
#  '[AdventureWorks2019].[HumanResources].[Department]',
#  '[AdventureWorks2019].[Production].[Document]',
#  '[AdventureWorks2019].[Sales].[SalesOrderDetail]',
#  '[AdventureWorks2019].[Person].[EmailAddress]',
#  '[AdventureWorks2019].[HumanResources].[Employee]',
#  '[AdventureWorks2019].[Sales].[SalesOrderHeader]',
#  '[AdventureWorks2019].[HumanResources].[EmployeeDepartmentHistory]']

# %%
len(list_of_tables)     #No. of tables
# Out:
# 91

# %%
#Establishing connection to postgres database
pg_driver = os.getenv('postgre_driver') 
pg_database = os.getenv('postgre_database') 
pg_server = os.getenv('postgre_server') 
pg_port = os.getenv('postgre_port') 
pg_uid = os.getenv('postgre_uid') 
pg_pwd = os.getenv('postgre_pwd') 

pg_engine = create_engine(f'postgresql://{pg_uid}:{pg_pwd}@{pg_server}:{pg_port}/{pg_database}')

# %%
#Loading tables to postgres
errors = []

for tbl in list_of_tables:
    try:
        rows_imported = 0
        #query and load save data to dataframe
        df = pd.read_sql_query(f'select * FROM {tbl}', mssql_engine)  
        df.to_sql(f'{tbl[21:]}', pg_engine, if_exists='replace', index=False)
        print(f'importing rows {rows_imported} to {rows_imported + len(df)}... for table {tbl}')
        rows_imported += len(df)
        print("Data imported successfully!")
    except Exception as e:
        error =  str(e) + ' ' + str(tbl)
        errors.append(error)
# Out:
# importing rows 0 to 316... for table [AdventureWorks2019].[HumanResources].[EmployeePayHistory]
# Data imported successfully!
# importing rows 0 to 27647... for table [AdventureWorks2019].[Sales].[SalesOrderHeaderSalesReason]
# Data imported successfully!
# importing rows 0 to 17... for table [AdventureWorks2019].[Sales].[SalesPerson]
# Data imported successfully!
# importing rows 0 to 5... for table [AdventureWorks2019].[Production].[Illustration]
# Data imported successfully!
# importing rows 0 to 13... for table [AdventureWorks2019].[HumanResources].[JobCandidate]
# Data imported successfully!
# importing rows 0 to 14... for table [AdventureWorks2019].[Production].[Location]
# Data imported successfully!
# importing rows 0 to 19972... for table [AdventureWorks2019].[Person].[Password]
# Data imported successfully!
# importing rows 0 to 163... for table [AdventureWorks2019].[Sales].[SalesPersonQuotaHistory]
# Data imported successfully!
# importing rows 0 to 19972... for table [AdventureWorks2019].[Person].[Person]
# Data imported successfully!
# importing rows 0 to 10... for table [AdventureWorks2019].[Sales].[SalesReason]
# Data imported successfully!
# importing rows 0 to 29... for table [AdventureWorks2019].[Sales].[SalesTaxRate]
# Data imported successfully!
# importing rows 0 to 19118... for table [AdventureWorks2019].[Sales].[PersonCreditCard]
# Data imported successfully!
# importing rows 0 to 10... for table [AdventureWorks2019].[Person].[vAdditionalContactInfo]
# Data imported successfully!
# importing rows 0 to 19972... for table [AdventureWorks2019].[Person].[PersonPhone]
# Data imported successfully!
# importing rows 0 to 290... for table [AdventureWorks2019].[HumanResources].[vEmployee]
# Data imported successfully!
# importing rows 0 to 10... for table [AdventureWorks2019].[Sales].[SalesTerritory]
# Data imported successfully!
# importing rows 0 to 290... for table [AdventureWorks2019].[HumanResources].[vEmployeeDepartment]
# Data imported successfully!
# importing rows 0 to 3... for table [AdventureWorks2019].[Person].[PhoneNumberType]
# Data imported successfully!
# importing rows 0 to 296... for table [AdventureWorks2019].[HumanResources].[vEmployeeDepartmentHistory]
# Data imported successfully!
# importing rows 0 to 18508... for table [AdventureWorks2019].[Sales].[vIndividualCustomer]
# Data imported successfully!
# importing rows 0 to 504... for table [AdventureWorks2019].[Production].[Product]
# Data imported successfully!
# importing rows 0 to 19972... for table [AdventureWorks2019].[Sales].[vPersonDemographics]
# Data imported successfully!
# importing rows 0 to 13... for table [AdventureWorks2019].[HumanResources].[vJobCandidate]
# Data imported successfully!
# importing rows 0 to 30... for table [AdventureWorks2019].[HumanResources].[vJobCandidateEmployment]
# Data imported successfully!
# importing rows 0 to 16... for table [AdventureWorks2019].[HumanResources].[vJobCandidateEducation]
# Data imported successfully!
# importing rows 0 to 1764... for table [AdventureWorks2019].[Production].[vProductAndDescription]
# Data imported successfully!
# importing rows 0 to 6... for table [AdventureWorks2019].[Production].[vProductModelCatalogDescription]
# Data imported successfully!
# importing rows 0 to 131... for table [AdventureWorks2019].[Production].[vProductModelInstructions]
# Data imported successfully!
# importing rows 0 to 17... for table [AdventureWorks2019].[Sales].[vSalesPerson]
# Data imported successfully!
# importing rows 0 to 17... for table [AdventureWorks2019].[Sales].[SalesTerritoryHistory]
# Data imported successfully!
# importing rows 0 to 14... for table [AdventureWorks2019].[Sales].[vSalesPersonSalesByFiscalYears]
# Data imported successfully!
# importing rows 0 to 181... for table [AdventureWorks2019].[Person].[vStateProvinceCountryRegion]
# Data imported successfully!
# importing rows 0 to 701... for table [AdventureWorks2019].[Sales].[vStoreWithDemographics]
# Data imported successfully!
# importing rows 0 to 753... for table [AdventureWorks2019].[Sales].[vStoreWithContacts]
# Data imported successfully!
# importing rows 0 to 16... for table [AdventureWorks2019].[Production].[ScrapReason]
# Data imported successfully!
# importing rows 0 to 712... for table [AdventureWorks2019].[Sales].[vStoreWithAddresses]
# Data imported successfully!
# importing rows 0 to 156... for table [AdventureWorks2019].[Purchasing].[vVendorWithContacts]
# Data imported successfully!
# importing rows 0 to 3... for table [AdventureWorks2019].[HumanResources].[Shift]
# Data imported successfully!
# importing rows 0 to 104... for table [AdventureWorks2019].[Purchasing].[vVendorWithAddresses]
# Data imported successfully!
# importing rows 0 to 4... for table [AdventureWorks2019].[Production].[ProductCategory]
# Data imported successfully!
# importing rows 0 to 5... for table [AdventureWorks2019].[Purchasing].[ShipMethod]
# Data imported successfully!
# importing rows 0 to 395... for table [AdventureWorks2019].[Production].[ProductCostHistory]
# Data imported successfully!
# importing rows 0 to 762... for table [AdventureWorks2019].[Production].[ProductDescription]
# Data imported successfully!
# importing rows 0 to 3... for table [AdventureWorks2019].[Sales].[ShoppingCartItem]
# Data imported successfully!
# importing rows 0 to 1596... for table [AdventureWorks2019].[dbo].[DatabaseLog]
# Data imported successfully!
# importing rows 0 to 1069... for table [AdventureWorks2019].[Production].[ProductInventory]
# Data imported successfully!
# importing rows 0 to 16... for table [AdventureWorks2019].[Sales].[SpecialOffer]
# Data imported successfully!
# importing rows 0 to 0... for table [AdventureWorks2019].[dbo].[ErrorLog]
# Data imported successfully!
# importing rows 0 to 395... for table [AdventureWorks2019].[Production].[ProductListPriceHistory]
# Data imported successfully!
# importing rows 0 to 538... for table [AdventureWorks2019].[Sales].[SpecialOfferProduct]
# Data imported successfully!
# importing rows 0 to 128... for table [AdventureWorks2019].[Production].[ProductModel]
# Data imported successfully!
# importing rows 0 to 6... for table [AdventureWorks2019].[Person].[AddressType]
# Data imported successfully!
# importing rows 0 to 181... for table [AdventureWorks2019].[Person].[StateProvince]
# Data imported successfully!
# importing rows 0 to 7... for table [AdventureWorks2019].[Production].[ProductModelIllustration]
# Data imported successfully!
# importing rows 0 to 1... for table [AdventureWorks2019].[dbo].[AWBuildVersion]
# Data imported successfully!
# importing rows 0 to 762... for table [AdventureWorks2019].[Production].[ProductModelProductDescriptionCulture]
# Data imported successfully!
# importing rows 0 to 2679... for table [AdventureWorks2019].[Production].[BillOfMaterials]
# Data imported successfully!
# importing rows 0 to 701... for table [AdventureWorks2019].[Sales].[Store]
# Data imported successfully!
# importing rows 0 to 101... for table [AdventureWorks2019].[Production].[ProductPhoto]
# Data imported successfully!
# importing rows 0 to 504... for table [AdventureWorks2019].[Production].[ProductProductPhoto]
# Data imported successfully!
# importing rows 0 to 113443... for table [AdventureWorks2019].[Production].[TransactionHistory]
# Data imported successfully!
# importing rows 0 to 4... for table [AdventureWorks2019].[Production].[ProductReview]
# Data imported successfully!
# importing rows 0 to 20777... for table [AdventureWorks2019].[Person].[BusinessEntity]
# Data imported successfully!
# importing rows 0 to 89253... for table [AdventureWorks2019].[Production].[TransactionHistoryArchive]
# Data imported successfully!
# importing rows 0 to 37... for table [AdventureWorks2019].[Production].[ProductSubcategory]
# Data imported successfully!
# importing rows 0 to 19614... for table [AdventureWorks2019].[Person].[BusinessEntityAddress]
# Data imported successfully!
# importing rows 0 to 460... for table [AdventureWorks2019].[Purchasing].[ProductVendor]
# Data imported successfully!
# importing rows 0 to 909... for table [AdventureWorks2019].[Person].[BusinessEntityContact]
# Data imported successfully!
# importing rows 0 to 38... for table [AdventureWorks2019].[Production].[UnitMeasure]
# Data imported successfully!
# importing rows 0 to 104... for table [AdventureWorks2019].[Purchasing].[Vendor]
# Data imported successfully!
# importing rows 0 to 20... for table [AdventureWorks2019].[Person].[ContactType]
# Data imported successfully!
# importing rows 0 to 109... for table [AdventureWorks2019].[Sales].[CountryRegionCurrency]
# Data imported successfully!
# importing rows 0 to 238... for table [AdventureWorks2019].[Person].[CountryRegion]
# Data imported successfully!
# importing rows 0 to 72591... for table [AdventureWorks2019].[Production].[WorkOrder]
# Data imported successfully!
# importing rows 0 to 8845... for table [AdventureWorks2019].[Purchasing].[PurchaseOrderDetail]
# Data imported successfully!
# importing rows 0 to 19118... for table [AdventureWorks2019].[Sales].[CreditCard]
# Data imported successfully!
# importing rows 0 to 8... for table [AdventureWorks2019].[Production].[Culture]
# Data imported successfully!
# importing rows 0 to 67131... for table [AdventureWorks2019].[Production].[WorkOrderRouting]
# Data imported successfully!
# importing rows 0 to 105... for table [AdventureWorks2019].[Sales].[Currency]
# Data imported successfully!
# importing rows 0 to 4012... for table [AdventureWorks2019].[Purchasing].[PurchaseOrderHeader]
# Data imported successfully!
# importing rows 0 to 13532... for table [AdventureWorks2019].[Sales].[CurrencyRate]
# Data imported successfully!
# importing rows 0 to 19820... for table [AdventureWorks2019].[Sales].[Customer]
# Data imported successfully!
# importing rows 0 to 16... for table [AdventureWorks2019].[HumanResources].[Department]
# Data imported successfully!
# importing rows 0 to 121317... for table [AdventureWorks2019].[Sales].[SalesOrderDetail]
# Data imported successfully!
# importing rows 0 to 19972... for table [AdventureWorks2019].[Person].[EmailAddress]
# Data imported successfully!
# importing rows 0 to 31465... for table [AdventureWorks2019].[Sales].[SalesOrderHeader]
# Data imported successfully!
# importing rows 0 to 296... for table [AdventureWorks2019].[HumanResources].[EmployeeDepartmentHistory]
# Data imported successfully!

# %%
errors #List of errors we faced during the extract-load process
# Out:
# ["(pyodbc.ProgrammingError) ('ODBC SQL type -151 is not yet supported.  column-index=1  type=-151', 'HY106')\n(Background on this error at: https://sqlalche.me/e/14/f405) [AdventureWorks2019].[Production].[ProductDocument]",
#  "(pyodbc.ProgrammingError) ('ODBC SQL type -151 is not yet supported.  column-index=6  type=-151', 'HY106')\n(Background on this error at: https://sqlalche.me/e/14/f405) [AdventureWorks2019].[Person].[Address]",
#  "(pyodbc.ProgrammingError) ('ODBC SQL type -151 is not yet supported.  column-index=0  type=-151', 'HY106')\n(Background on this error at: https://sqlalche.me/e/14/f405) [AdventureWorks2019].[Production].[Document]",
#  "(pyodbc.ProgrammingError) ('ODBC SQL type -151 is not yet supported.  column-index=3  type=-151', 'HY106')\n(Background on this error at: https://sqlalche.me/e/14/f405) [AdventureWorks2019].[HumanResources].[Employee]"]

# %%
#Extracting table name for transformations
tables_to_transform = []

for err in errors:
    tables_to_transform.append(err[168:])

tables_to_transform
# Out:
# ['[AdventureWorks2019].[Production].[ProductDocument]',
#  '[AdventureWorks2019].[Person].[Address]',
#  '[AdventureWorks2019].[Production].[Document]',
#  '[AdventureWorks2019].[HumanResources].[Employee]']

# %%
#Transforming Data 

sql = """   SELECT ProductID
            ,CAST(DocumentNode AS VARBINARY(4000)) AS DocumentNode
            ,ModifiedDate
            FROM [AdventureWorks2019].[Production].[ProductDocument];
                """

df = pd.read_sql(sql, mssql_engine)
df.dtypes
df.to_sql('[Production].[ProductDocument]', pg_engine, if_exists='replace', index=False)
# Out:
# 32

# %%
pg_engine.dispose()         #Close the connection
mssql_engine.dispose()      #Close the connection
